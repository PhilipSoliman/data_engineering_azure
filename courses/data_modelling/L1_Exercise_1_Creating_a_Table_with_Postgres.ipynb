# %% [markdown]
# # Lesson 1 Exercise 1: Creating a Table with PostgreSQL
#
# <img src="images/postgresSQLlogo.png" width="250" height="250">

# %% [markdown]
# ### Walk through the basics of PostgreSQL. You will need to complete the following tasks:<li> Create a table in PostgreSQL, <li> Insert rows of data <li> Run a simple SQL query to validate the information. <br>
# `#####` denotes where the code needs to be completed.

# %% [markdown]
# #### Import the library
# *Note:* An error might popup after this command has executed. If it does, read it carefully before ignoring.

# %%
import psycopg2
from src.database import get_connection, get_cursor

# %%
conn = get_connection()
conn.set_session(autocommit=True)

# %%
cur = get_cursor(conn)

# %%
## TO-DO: Finish writing the CREATE TABLE statement with the correct arguments
try: 
    cur.execute("CREATE TABLE IF NOT EXISTS song_library (song_title VARCHAR, artist_name VARCHAR, release_year INT, album_name VARCHAR, is_single BOOLEAN);")
except psycopg2.Error as e: 
    print("Error: Issue creating table")
    print (e)

# %%
try:
    cur.execute("SELECT count(*) FROM song_library;")
except psycopg2.Error as e:
    print("Error: Issue selecting count from table")
    print (e)

print(cur.fetchall())
# Out:
# [(0,)]

# %% [markdown]
# ### Insert the following two rows in the table
# `First Row:  "Across The Universe", "The Beatles", "1970", "Let It Be", "False"`
#
# `Second Row: "Think For Yourself", "The Beatles", "1965", "Rubber Soul", "False"`

# %%
## TO-DO: Finish the INSERT INTO statement with the correct arguments
rows = [
    ["Across The Universe", "The Beatles", 1970, "Let It Be", False],
    ["Think For Yourself", "The Beatles", 1965, "Rubber Soul", False]
]
for row in rows:
    try: 
        cur.execute("INSERT INTO song_library (song_title, artist_name, release_year, album_name, is_single)" \
                    "VALUES (%s, %s, %s, %s, %s)", row)
        cur.execute("SELECT count(*) FROM song_library;")
    except psycopg2.Error as e: 
        print("Error: Inserting Rows")
        print(e)
print(f"Done inserting. Total number of rows: {cur.fetchall()}")
# Out:
# Done inserting. Total number of rows: [(6,)]

# %% [markdown]
# ### TO-DO: Validate your data was inserted into the table.

# %%
## TO-DO: Finish the SELECT * Statement 
try: 
    cur.execute("SELECT * FROM song_library")
except psycopg2.Error as e: 
    print("Error: select *")
    print (e)

row = cur.fetchone()
while row:
   print(row)
   row = cur.fetchone()
# Out:
# ('Across The Universe', 'The Beatles', 1970, 'Let It Be', False)
# ('Think For Yourself', 'The Beatles', 1965, 'Rubber Soul', False)
# ('Across The Universe', 'The Beatles', 1970, 'Let It Be', False)
# ('Think For Yourself', 'The Beatles', 1965, 'Rubber Soul', False)
# ('Across The Universe', 'The Beatles', 1970, 'Let It Be', False)
# ('Think For Yourself', 'The Beatles', 1965, 'Rubber Soul', False)

# %% [markdown]
# ### And finally close your cursor and connection.

# %%
cur.close()
conn.close()
